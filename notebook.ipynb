# %%
from main import *

# %%
# Define the file path
file_path = 'datasets/IGPM.csv'

# Create an instance of the TimeSeries class
igpm = TimeSeries(file_path, 'IGP-M % Mensal (desde 1995)', 'IGP-M')

train, test = igpm.train_test_split(train_size=0.75, verbose=False)

igpm.naive_model(train, test, verbose=False)

igpm.arima_model(order=(2, 0, 1), train=train, test=test, verbose=True)
# Out:
# ---
# Analisando série temporal com ARIMA(2,0,1)...
# ---
# A série temporal é estacionária
# ---
# Metrics:
# Erro Quadrático Médio (MSE): 0.6842
# Erro Percentual Absoluto Médio (MAPE): 236.08%
# Acurácia Binária da Tendência: 46.67% (M. Class Acc: 50.00%)
# ---
# Naive Model:
# ---
# Metrics:
# Erro Quadrático Médio (MSE): 0.8031
# Erro Percentual Absoluto Médio (MAPE): 362.88%
# Acurácia Binária da Tendência: 46.67% (M. Class Acc: 50.00%)
# ({'mse': 0.6842154411867032, 'mape': 2.360771485241482},
#  {'acc': np.float64(0.4666666666666667), 'major_class_acc': np.float64(0.5)},
#  np.float64(3.511653593094852),
#  0      0.245748
#  1      0.550225
#  2     -0.030424
#  3      1.111051
#  4     -1.032426
#           ...
#  356    0.201030
#  357    0.893260
#  358    0.063435
#  359   -0.171449
#  360   -0.583467
#  Length: 361, dtype: float64)
